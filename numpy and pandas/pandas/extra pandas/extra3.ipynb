# %%
import pandas
df1=pandas.read_json("supermarkets.json")
df1.set_index("Address",inplace=True)
df1
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df1.loc["735 Dolores St":"332 Hill St","Country":"ID"]
# Out:
#                Country Employees ID
# Address
# 735 Dolores St     USA        15  2
# 332 Hill St        USA        25  3

# %%
df1.loc["735 Dolores St","Country"]
# Out:
# 'USA'

# %%
df1.loc[:,"Country"]
# Out:
# Address
# 3666 21st St       USA
# 735 Dolores St     USA
# 332 Hill St        USA
# 3995 23rd St       USA
# 1056 Sanchez St    USA
# 551 Alvarado St    USA
# Name: Country, dtype: object

# %%
y=list(df1.loc[:,"Country"])
print(y)
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df1
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df1.iloc[1:3,1:3]
# Out:
#                Country  Employees
# Address
# 735 Dolores St     USA         15
# 332 Hill St        USA         25

# %%
df1.ix[3,"Name"]
# Out:
# D:\last\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# "Ben's Shop"

# %%
df1.drop("Country",1)
# Out:
#                           City  Employees  ID         Name             State
# Address
# 3666 21st St     San Francisco          8   1      Madeira          CA 94114
# 735 Dolores St   San Francisco         15   2  Bready Shop          CA 94119
# 332 Hill St      San Francisco         25   3  Super River  California 94114
# 3995 23rd St     San Francisco         10   4   Ben's Shop          CA 94114
# 1056 Sanchez St  San Francisco         12   5      Sanchez        California
# 551 Alvarado St  San Francisco         20   6   Richvalley          CA 94114

# %%
df1.drop("3995 23rd St",0)
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df1.drop(df1.index[0:2],0)
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df1.drop(df1.columns[0:3],1)
# Out:
#                  ID         Name             State
# Address
# 3666 21st St      1      Madeira          CA 94114
# 735 Dolores St    2  Bready Shop          CA 94119
# 332 Hill St       3  Super River  California 94114
# 3995 23rd St      4   Ben's Shop          CA 94114
# 1056 Sanchez St   5      Sanchez        California
# 551 Alvarado St   6   Richvalley          CA 94114

# %%
df1["cont"]=["north amrc","north amrc","north amrc","north amrc","north amrc","north amrc"]
df1
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State        cont
# Address
# 3666 21st St             CA 94114  north amrc
# 735 Dolores St           CA 94119  north amrc
# 332 Hill St      California 94114  north amrc
# 3995 23rd St             CA 94114  north amrc
# 1056 Sanchez St        California  north amrc
# 551 Alvarado St          CA 94114  north amrc

# %%
df1["cont"]=df1.shape[0]*["north amrc"]
df1
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State        cont
# Address
# 3666 21st St             CA 94114  north amrc
# 735 Dolores St           CA 94119  north amrc
# 332 Hill St      California 94114  north amrc
# 3995 23rd St             CA 94114  north amrc
# 1056 Sanchez St        California  north amrc
# 551 Alvarado St          CA 94114  north amrc

# %%
df1["cont"]=df1["Country"]+","+"north amrc"
df1
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State            cont
# Address
# 3666 21st St             CA 94114  USA,north amrc
# 735 Dolores St           CA 94119  USA,north amrc
# 332 Hill St      California 94114  USA,north amrc
# 3995 23rd St             CA 94114  USA,north amrc
# 1056 Sanchez St        California  USA,north amrc
# 551 Alvarado St          CA 94114  USA,north amrc

# %%
#add new raw
#:first trans
df1_t=df1.T
df1_t
# Out:
# Address      3666 21st St  735 Dolores St       332 Hill St    3995 23rd St  \
# City        San Francisco   San Francisco     San Francisco   San Francisco
# Country               USA             USA               USA             USA
# Employees               8              15                25              10
# ID                      1               2                 3               4
# Name              Madeira     Bready Shop       Super River      Ben's Shop
# State            CA 94114        CA 94119  California 94114        CA 94114
# cont       USA,north amrc  USA,north amrc    USA,north amrc  USA,north amrc
#
# Address   1056 Sanchez St 551 Alvarado St
# City        San Francisco   San Francisco
# Country               USA             USA
# Employees              12              20
# ID                      5               6
# Name              Sanchez      Richvalley
# State          California        CA 94114
# cont       USA,north amrc  USA,north amrc

# %%
#second: add new column
df1_t["mmm"]=["aaa","bbbb",10,7,"ccc","ggg","fff"]
df1_t
# Out:
# Address      3666 21st St  735 Dolores St       332 Hill St    3995 23rd St  \
# City        San Francisco   San Francisco     San Francisco   San Francisco
# Country               USA             USA               USA             USA
# Employees               8              15                25              10
# ID                      1               2                 3               4
# Name              Madeira     Bready Shop       Super River      Ben's Shop
# State            CA 94114        CA 94119  California 94114        CA 94114
# cont       USA,north amrc  USA,north amrc    USA,north amrc  USA,north amrc
#
# Address   1056 Sanchez St 551 Alvarado St   mmm
# City        San Francisco   San Francisco   aaa
# Country               USA             USA  bbbb
# Employees              12              20    10
# ID                      5               6     7
# Name              Sanchez      Richvalley   ccc
# State          California        CA 94114   ggg
# ...

# %%
# Third tans again
df1=df1_t.T
df1
# Out:
#                           City Country Employees ID         Name  \
# Address
# 3666 21st St     San Francisco     USA         8  1      Madeira
# 735 Dolores St   San Francisco     USA        15  2  Bready Shop
# 332 Hill St      San Francisco     USA        25  3  Super River
# 3995 23rd St     San Francisco     USA        10  4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA        12  5      Sanchez
# 551 Alvarado St  San Francisco     USA        20  6   Richvalley
# mmm                        aaa    bbbb        10  7          ccc
#
#                             State            cont
# Address
# 3666 21st St             CA 94114  USA,north amrc
# 735 Dolores St           CA 94119  USA,north amrc
# 332 Hill St      California 94114  USA,north amrc
# 3995 23rd St             CA 94114  USA,north amrc
# 1056 Sanchez St        California  USA,north amrc
# 551 Alvarado St          CA 94114  USA,north amrc
# mmm                           ggg             fff
